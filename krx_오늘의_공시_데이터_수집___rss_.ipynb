# %%
#krx_오늘의 공시 크롤링

# rss 이용

#. feedparser 이용

# %%
# !pip install feedparser
# !pip install requests
# !pip install datetime
import requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 12.7 MB/s eta 0:00:00
# ...

# %%
import datetime
import feedparser
from datetime import *

def update_kind_krx():

  url_data='http://kind.krx.co.kr:80/disclosure/rsstodaydistribute.do?method=searchRssTodayDistribute&repIsuSrtCd=&mktTpCd=0&searchCorpName=&currentPageSize=3000'


  start = datetime.now
  res = requests.get(url_data)
  data = feedparser.parse(res.text)
  data=data['entries']
  data_count = 0
  

  print (data)
  return data

# %%
update_kind_krx()
# Out:
# [{'title': '[유]롯데케미칼 임원ㆍ주요주주특정증권등소유상황보고서', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': '[유]롯데케미칼 임원ㆍ주요주주특정증권등소유상황보고서'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://kind.krx.co.kr:80/common/disclsviewer.do?method=searchInitInfo&acptNo=20230203000420&docno='}], 'link': 'http://kind.krx.co.kr:80/common/disclsviewer.do?method=searchInitInfo&acptNo=20230203000420&docno=', 'published': 'Fri, 03 Feb 2023 14:55:00 +0900', 'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=3, tm_hour=5, tm_min=55, tm_sec=0, tm_wday=4, tm_yday=34, tm_isdst=0), 'authors': [{'name': '[유]롯데케미칼'}], 'author': '[유]롯데케미칼', 'author_detail': {'name': '[유]롯데케미칼'}, 'tags': [{'term': '지분공시', 'scheme': None, 'label': None}], 'language': 'ko', 'updated': 'Fri, 03 Feb 2023 14:55:00 +0900', 'updated_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=3, tm_hour=5, tm_min=55, tm_sec=0, tm_wday=4, tm_yday=34, tm_isdst=0)}, {'title': '[유]롯데케미칼 임원ㆍ주
# ...
